# %% [markdown]
# ### Importing the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_excel("D:\Data Projects\Practice Files\Supermarket Sales\supermarket_sales - Sheet1.xlsx")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date      Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46:00  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16:00  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22:00     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33:00     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28:00     Cash
#
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# ### Cleaning the Dataset

# %%
## checking for duplicates

df.duplicated().sum()
# Out:
# 0

# %%
## dealing with outliers

q1 = df["Rating"].quantile(0.25)
q3 = df["Rating"].quantile(0.75)

# %%
iqr = q3 - q1

# %%
upper_limit = q3 + (1.5*iqr)
lower_limit = q3 - (1.5*iqr)

print(lower_limit, upper_limit)
# Out:
# 4.0 13.0

# %%
df.loc[(df["Rating"] > upper_limit) | (df["Rating"] < lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %%
## Checking for outliers in the gross income column

q1 = df["gross income"].quantile(0.25)
q3 = df["gross income"].quantile(0.75)

iqr = q3 - q1

upper_limit = q3 + (1.5*iqr)
lower_limit = q3 - (1.5*iqr)

print(lower_limit, upper_limit)
# Out:
# -2.3353125000000006 47.2258125

# %%
df.loc[(df["gross income"] > upper_limit) | (df["gross income"] < lower_limit)]
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 166  234-65-2137      C  Naypyitaw        Normal    Male   Home and lifestyle
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 357  554-42-2417      C  Naypyitaw        Normal  Female    Sports and travel
# 422  271-88-8734      C  Naypyitaw        Member  Female  Fashion accessories
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 792  744-16-7898      B   Mandalay        Normal  Female   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%     Total       Date      Time      Payment  \
# 166       95.58        10  47.790  1003.590 2019-01-16  13:32:00         Cash
# ...

# %%
df1 = df.loc[(df["gross income"] < upper_limit) & (df["gross income"] > lower_limit)]
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
print("before removing outliers:",len(df))
print("after removing outliers:", len(df1))
print("outliers:", len(df) - len(df1))
# Out:
# before removing outliers: 1000
# after removing outliers: 991
# outliers: 9

# %%
sns.boxplot(df1["gross income"])
# Out:
# <Axes: >

# %% [markdown]
# ### Visualizing the Dataset

# %%
sales = df1.drop(["gross margin percentage"], axis = 1)

# %% [markdown]
# ##### Frequency of Ratings

# %%
plt.figure()
plt.hist(sales["Rating"], bins = 15)
plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.grid(True)
plt.title("Frequency of Ratings")
# Out:
# Text(0.5, 1.0, 'Frequency of Ratings')

# %% [markdown]
# ##### Income comparison between genders

# %%
plt.figure(figsize = (7,7))
plt.barh(sales["Gender"], sales["gross income"], color = ("green"))
plt.xlabel("Income")
plt.ylabel("Customer Gender")
plt.grid(True)
plt.title("Comparison between Customer Gender and Income")
plt.show()

# %% [markdown]
# ##### Comparison between Profit and City

# %%
sales["Sales"] = sales["Unit price"] * sales["Quantity"]

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
plt.figure(figsize=(7,7))
plt.barh(sales["City"], sales["Sales"])
plt.xlabel("Profit")
plt.ylabel("Location (City)")
plt.grid(True)
plt.title("Profit by City")
# Out:
# Text(0.5, 1.0, 'Profit by City')

# %% [markdown]
# ##### Relationship between Product Line and Sales

# %%
plt.figure(figsize=(7,7))
plt.barh(sales["Product line"], sales["Sales"])
plt.xlabel("Profit")
plt.ylabel("Product Category")
plt.grid(True)
plt.title("Profit by Product Category")
# Out:
# Text(0.5, 1.0, 'Profit by Product Category')

# %% [markdown]
# ##### Comparison by Tax and Profit

# %%
plt.figure(figsize=(7,7))
plt.scatter(sales["Tax 5%"], sales["Sales"], s = 200)
plt.scatter(sales["Tax 5%"], sales["gross income"], s = 500, marker = "3")
plt.xlabel("Tax")
plt.ylabel("Profit and Gross Income")
plt.grid(True)
plt.title("Relationship between Tax and Profit")
plt.show()

# %% [markdown]
# ##### Comparison between Payment method and Sales

# %%
plt.figure(figsize=(7,7))
plt.barh(sales["Payment"], sales["Sales"], color = "grey")
plt.xlabel("Profit")
plt.ylabel("Payment Method")
plt.grid(True)
plt.title("Profit by Payment Method")
# Out:
# Text(0.5, 1.0, 'Profit by Payment Method')

# %% [markdown]
# ##### Finding the highest sales return

# %%
plt.figure(figsize=(7,7))
plt.hist(sales["Sales"], color = "maroon", bins= 20)
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.grid(True)
plt.title("Frequency of Profit")
plt.show()

# %% [markdown]
# ### Finding the relationship matrix for the dataset

# %%
sales.corr()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_3672\3143902651.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales.corr()
#               Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price      1.000000 -0.011506  0.623355  0.623355  0.623355
# Quantity       -0.011506  1.000000  0.699290  0.699290  0.699290
# Tax 5%          0.623355  0.699290  1.000000  1.000000  1.000000
# Total           0.623355  0.699290  1.000000  1.000000  1.000000
# cogs            0.623355  0.699290  1.000000  1.000000  1.000000
# gross income    0.623355  0.699290  1.000000  1.000000  1.000000
# Rating         -0.002527 -0.009694 -0.026092 -0.026092 -0.026092
# Sales           0.623355  0.699290  1.000000  1.000000  1.000000
#
#               gross income    Rating     Sales
# ...

# %% [markdown]
# ### Building Linear Regression Model

# %%
sales1 = sales.drop(["Invoice ID", "Branch", "City", 'Customer type', "Date","Time", 'Gender', 'Product line', "Payment"], axis = 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X = sales1.drop(["Rating"], axis = 1)
y = sales1["Rating"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=15)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import accuracy_score

# %%
lr.predict(X_test)
# Out:
# array([7.01191045, 6.95631071, 7.09851647, 6.9545637 , 6.95534168,
#        7.00083218, 7.06864563, 6.99171238, 6.95628949, 7.01056054,
#        6.86332904, 7.01192964, 7.11744321, 6.94134701, 7.07952945,
#        7.15890172, 7.12770604, 7.01302965, 6.90252219, 6.96903737,
#        7.10337787, 7.01607429, 7.00157264, 6.96208513, 6.97274579,
#        7.00602899, 6.98884749, 7.02159874, 6.85438702, 7.10251566,
#        7.01370591, 7.00578127, 7.01790607, 6.84651157, 7.07474667,
#        6.99099229, 7.01664185, 6.97524631, 7.00932342, 7.00984179,
#        7.00230795, 6.86732541, 6.94166761, 6.98984284, 6.90969116,
#        7.03698805, 7.20609692, 6.99880647, 6.98494009, 7.17827924,
#        7.02427412, 7.01867845, 6.9823113 , 6.94085271, 6.96102126,
#        7.05586447, 7.00334904, 6.90046377, 7.18370921, 6.98606425,
#        7.00766427, 7.03742866, 7.03946014, 7.00546089, 6.94962042,
#        7.04657451, 7.25183378, 6.97818734, 7.03762834, 6.99705323,
# ...

# %%
pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, pred)
# Out:
# -0.005712762533983895

# %% [markdown]
# #### Plotting the predicted values

# %%
plt.figure(figsize = (10,10))
plt.scatter(pred, y_test, s = 250, color = "green")
plt.xlabel("Predicted Value")
plt.ylabel("Ratings")
plt.grid()
plt.title("Predicted Value vs Ratings")
plt.show()
